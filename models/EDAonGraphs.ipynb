# %%
from common import plot_subgraph, plot_graph_adj_matrix
from torch_geometric.datasets import GitHub, Twitch

# %%
twitch = Twitch(root='../data/Twitch', name='EN')
twitch.data
# Out:
# Data(x=[7126, 128], edge_index=[2, 77774], y=[7126])

# %%
plot_subgraph(twitch.data, list(range(200)))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
plot_graph_adj_matrix(twitch.data)

# %%
from common import plot_features_distributions

plot_features_distributions(twitch.data, list(range(10, 20)), plot_type='violin')
